# %% [markdown]
# # Data Exploration
#
# Use this notebook to inspect the standardized Market Entry Agent dataset.

# %%
import pandas as pd

df = pd.read_csv('../data/processed/market_entry_dataset.csv')
df.head()

# %%
df.groupby('source_type').size()
